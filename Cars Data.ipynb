# %%
import pandas as pd

car=pd.read_csv(r"C:\Users\Harold\Desktop\python\projects\Dataset  Project 2  Cars Data Analysis.csv")
car

car.shape

print("Data Cleaning - Find null values in the columns and fill it with the mean of tthat column")

clean=car.isnull().sum()

print(clean)

fillnullValues= car.fillna({'Cylinders':car['Cylinders'].mean()},inplace=True)
#or alternatively #####car['Cylinders'].fillna(car['Cylinders'].mean(),inplace=True)
####
print(fillnullValues)



print("Check and output the count of the different types of 'Make's in the dataset")
makes=car['Make'].value_counts()
print(makes)

print("Show all the data where the origin is Asia or Europe ")
origin=car[car['Origin'].isin(['Asia','Europe'])]
print(origin)


print("Remove all records where weight is above 4000 ")
car= car[~(car['Weight']>4000)]

print(car.shape)

 
print("Apply a function to increase MPG_City column by 3 ")

print(car['MPG_City'])
car['MPG_City'] =car['MPG_City'].apply(lambda x:x+3)
print(car['MPG_City'])
# Out:
# Data Cleaning - Find null values in the columns and fill it with the mean of tthat column
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64
# None
# Check and output the count of the different types of 'Make's in the dataset
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# ...
